# %% [markdown]
# Load Roboflow Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="o8Ai44BplOHOjwC4fT08")
project = rf.workspace("pscm1").project("defect_dataset-1h1in")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# /Users/szeqing/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 0.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Defect_Dataset-2 in yolov8:: 100%|██████████| 279/279 [00:01<00:00, 143.07it/s]

# %% [markdown]
# Model Training

# %%
from ultralytics import YOLO

#load model
model = YOLO("yolov8n.pt")

#train model
model.train(
    data="/Users/szeqing/Desktop/IDP/PSC-M1/Defect_Dataset-1",
    epochs=100,
    imgsz=640,
    batch=16,
    plots=True,
    name="Defect_Dataset-1",
)
# Out:
# Ultralytics 8.4.47 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1)
# ...

# %%
model_path= r"/Users/szeqing/Desktop/IDP/PSC-M1/runs/detect/Defect_Dataset-1/weights/best.pt"
image_path=r"/Users/szeqing/Desktop/IDP/PSC-M1/Defect_Dataset-1/test/images"
# !yolo task=detect mode=predict model="{model_path}" source="{image_path}"
# Out:
# Python(3013) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Ultralytics 8.4.47 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/6 /Users/szeqing/Desktop/IDP/PSC-M1/Defect_Dataset-1/test/images/IMG_8229_jpg.rf.d300927bf85f5fb6bcf1107a49a49b00.jpg: 640x640 1 Non-defect, 54.9ms
# image 2/6 /Users/szeqing/Desktop/IDP/PSC-M1/Defect_Dataset-1/test/images/IMG_8241_jpg.rf.c1a28e60ca03fb736a1038d450722198.jpg: 640x640 1 Non-defect, 45.8ms
# image 3/6 /Users/szeqing/Desktop/IDP/PSC-M1/Defect_Dataset-1/test/images/IMG_8265_jpg.rf.d1c49193661ce728fb02e56bb45b6347.jpg: 640x640 1 Defect, 60.0ms
# image 4/6 /Users/szeqing/Desktop/IDP/PSC-M1/Defect_Dataset-1/test/images/IMG_8275_jpg.rf.a7e6a8077789a9af1e8cfcd6cf468447.jpg: 640x640 1 Defect, 55.2ms
# ...
