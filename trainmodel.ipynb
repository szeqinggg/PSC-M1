# %% [markdown]
# Load Roboflow Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="o8Ai44BplOHOjwC4fT08")
project = rf.workspace("pscm1").project("medicinetype_dataset-msubz")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 0.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to MedicineType_Dataset-2 in yolov8:: 100%|██████████| 217/217 [00:00<00:00, 2650.64it/s]

# %% [markdown]
# Model Training

# %%
from ultralytics import YOLO

#load model
model = YOLO("yolov8n.pt")

#train model
model.train(
    data="/Users/szeqing/Desktop/IDP/PSC-M1/MedicineType_Dataset-1",
    epochs=100,
    imgsz=640,
    batch=16,
    plots=True,
    name="Medicine_Dataset-1",
)
# Out:
# Ultralytics 8.4.47 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1)
# ...

# %%
model_path= r"/Users/szeqing/Desktop/IDP/PSC-M1/runs/detect/Medicine_Dataset-1/weights/best.pt"
image_path=r"/Users/szeqing/Desktop/IDP/PSC-M1/MedicineType_Dataset-1/test/images"
# !yolo task=detect mode=predict model="{model_path}" source="{image_path}"
# Out:
# Python(97534) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Ultralytics 8.4.47 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/4 /Users/szeqing/Desktop/IDP/PSC-M1/MedicineType_Dataset-1/test/images/IMG_8218_jpg.rf.5991c93dff43fa8065e8e2fe60a88da0.jpg: 640x640 1 Actal Plus, 214.3ms
# image 2/4 /Users/szeqing/Desktop/IDP/PSC-M1/MedicineType_Dataset-1/test/images/IMG_8248_jpg.rf.49cb91aa9b6a49026910ed803a70fda8.jpg: 640x640 1 Actal Plus, 883.3ms
# image 3/4 /Users/szeqing/Desktop/IDP/PSC-M1/MedicineType_Dataset-1/test/images/IMG_8291_jpg.rf.1b69d3411b8766aeb74cd247e76983ba.jpg: 640x640 1 YSP Prednisolone, 367.5ms
# image 4/4 /Users/szeqing/Desktop/IDP/PSC-M1/MedicineType_Dataset-1/test/images/IMG_8298_jpg.rf.83cb52de699d3a89778a1569305f198a.jpg: 640x640 1 YSP Prednisolone, 420.4ms
# ...
